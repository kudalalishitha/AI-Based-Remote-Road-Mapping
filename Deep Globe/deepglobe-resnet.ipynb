# %% [markdown]
# *Importing Necessary Libraries*

# %%
# %pip install numpy matplotlib tensorflow pillow keras scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (3.10.0)
# Requirement already satisfied: tensorflow in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (2.18.0)
# Requirement already satisfied: pillow in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (11.1.0)
# Requirement already satisfied: keras in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (3.8.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (65.5.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: rich in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from keras) (13.9.4)
# Requirement already satisfied: optree in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: namex in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from keras) (0.0.8)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#      ---------------------------------------- 41.2/41.2 MB 6.4 MB/s eta 0:00:00
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      -------------------------------------- 301.8/301.8 kB 6.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\kudal\onedrive\desktop\project\deep_globe_detection\env\lib\site-packages (22.3.1)
# Collecting pip
#   Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-25.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from PIL import Image

import tensorflow as tf
from sklearn.model_selection import train_test_split

from keras.optimizers import Adam
from keras.metrics import Recall, Precision
from keras import backend as K
from keras.layers import (Input, Conv2D, BatchNormalization, 
                          Activation, MaxPool2D, Conv2DTranspose, 
                          Concatenate)
from keras.models import Model
from keras.layers import LeakyReLU


# If you have GPU(s), make sure TensorFlow sees them:
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Name: ", tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available:  1
# Name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# *Loading Dataset*

# %%
H = 256
W = 256
BATCH_SIZE = 8
LEARNING_RATE = 1e-4
EPOCHS = 10

DATA_PATH = '/kaggle/input/deepglobe-road-extraction-dataset/train'  # <-- Adapt if needed

# %% [markdown]
# *Segmentation evaluation metrics: Intersection over Union (IoU) and Soft Dice Coefficient & Loss*

# %%
smooth = 1e-15

def iou(y_true, y_pred):
    """Intersection over Union."""
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou_value = (intersection + smooth) / (union + smooth)
    return tf.ensure_shape(iou_value, shape=())

def soft_dice_coef(y_true, y_pred, smooth=1e-6):
    intersection = tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    return (2. * intersection + smooth) / (denominator + smooth)

def soft_dice_loss(y_true, y_pred):
    return 1.0 - soft_dice_coef(y_true, y_pred)

# %% [markdown]
# *Data Augmentation*

# %%
def load_data(data_path, split=0.2):
    """Load and split data into train/val/test."""
    images = sorted(glob(data_path + '/*sat.jpg'))
    masks = sorted(glob(data_path + '/*mask.png'))

    # Splitting
    train_x, val_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, val_y = train_test_split(masks, test_size=0.2, random_state=42)
    
    train_x, test_x = train_test_split(train_x, test_size=0.2, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=0.2, random_state=42)
    
    return (train_x, train_y), (val_x, val_y), (test_x, test_y)

(train_x, train_y), (val_x, val_y), (test_x, test_y) = load_data(DATA_PATH)
print(f"Train size: {len(train_x)}, Val size: {len(val_x)}, Test size: {len(test_x)}")
# Out:
# Train size: 3984, Val size: 1246, Test size: 996

# %% [markdown]
# *Creating TensorFlow data pipeline for loading, preprocessing, augmenting, and batching image-mask pairs for a segmentation task*

# %%
def read_image(path):
    """Reads and resizes the input image."""
    try:
        img = Image.open(path)
        img = img.resize((W, H))
        x = np.array(img, dtype=np.float32) / 255.0
        return x
    except Exception as e:
        print(f'Error while reading image: {e}')
        return None

def read_mask(path):
    """Reads and resizes the input mask."""
    try:
        mask = Image.open(path).convert('L')
        mask = mask.resize((W, H))
        x = np.array(mask, dtype=np.float32) / 255.0
        x = np.expand_dims(x, axis=-1)
        return x
    except Exception as e:
        print(f'Error while reading mask: {e}')
        return None

def tf_parse(x, y):
    """Wrapper to parse images in a TensorFlow graph."""
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

# <-- ADDED: Define an augmentation function using TensorFlow ops
def random_flip(x, y):
    """
    Randomly flips the image and mask horizontally or vertically.
    """
    # Random horizontal flip
    if tf.random.uniform(()) > 0.5:
        x = tf.image.flip_left_right(x)
        y = tf.image.flip_left_right(y)

    # Random vertical flip
    if tf.random.uniform(()) > 0.5:
        x = tf.image.flip_up_down(x)
        y = tf.image.flip_up_down(y)

    return x, y

def tf_dataset(X, Y, batch=BATCH_SIZE, repeat=False, augment=False):  # <-- CHANGED
    """
    Create a TF dataset from filenames.

    Args:
        X: List of input image paths.
        Y: List of corresponding mask paths.
        batch: Batch size.
        repeat: Whether to repeat the dataset indefinitely.
        augment: Whether to apply data augmentation (flip).
    """
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    
    if augment:  # <-- ADDED
        dataset = dataset.map(random_flip, num_parallel_calls=tf.data.AUTOTUNE)

    if repeat:
        dataset = dataset.repeat()  # Repeat indefinitely for training

    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# <-- CHANGED: Pass 'augment=True' for the training dataset
train_dataset = tf_dataset(train_x, train_y, batch=BATCH_SIZE, repeat=True, augment=True)
val_dataset   = tf_dataset(val_x, val_y, batch=BATCH_SIZE, repeat=True, augment=False)

train_steps = np.ceil(len(train_x) / BATCH_SIZE).astype(int)
val_steps   = np.ceil(len(val_x) / BATCH_SIZE).astype(int)

print(f"Train steps per epoch: {train_steps}")
print(f"Validation steps per epoch: {val_steps}")
# Out:
# Train steps per epoch: 498
# Validation steps per epoch: 156

# %% [markdown]
# *Model Architecture*

# %%
from tf.keras.layers import Input, Conv2D, BatchNormalization, LeakyReLU, Add, GlobalAveragePooling2D, Dense, MaxPool2D, Conv2DTranspose, Concatenate
from tf.keras.models import Model
from tf.keras.optimizers import Adam
from tf.keras.metrics import Recall, Precision

def conv_block(x, filters, kernel_size=3, padding='same'):
    """(Conv2D -> BN -> Activation) * 2 block."""
    x = Conv2D(filters, kernel_size, padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
    
    x = Conv2D(filters, kernel_size, padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(x, filters):
    """Residual block with skip connection."""
    res = Conv2D(filters, (1,1), padding='same')(x)
    res = BatchNormalization()(res)
    
    x = conv_block(x, filters)
    x = Add()([x, res])  # Skip connection
    x = LeakyReLU(alpha=0.1)(x)
    return x

def encoder_block(x, filters):
    """Encoder block: residual block + maxpool."""
    c = residual_block(x, filters)
    p = MaxPool2D((2, 2))(c)
    return c, p

def decoder_block(x, skip_features, filters):
    """Decoder block: transpose conv + concat + residual block."""
    x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
    x = Concatenate()([x, skip_features])
    x = residual_block(x, filters)
    return x

def build_resnet(input_shape=(256, 256, 3)):
    """Build a ResNet-like U-Net."""
    inputs = Input(input_shape)
    
    # Encoder
    c1, p1 = encoder_block(inputs, 64)
    c2, p2 = encoder_block(p1,   128)
    c3, p3 = encoder_block(p2,   256)
    c4, p4 = encoder_block(p3,   512)
    
    # Bottleneck
    bn = residual_block(p4, 1024)
    
    # Decoder
    d1 = decoder_block(bn, c4, 512)
    d2 = decoder_block(d1, c3, 256)
    d3 = decoder_block(d2, c2, 128)
    d4 = decoder_block(d3, c1, 64)
    
    # Output
    outputs = Conv2D(1, (1, 1), padding='same', activation='sigmoid')(d4)
    
    model = Model(inputs, outputs)
    return model

# Instantiate and compile the model
H, W = 256, 256  # Define height & width
LEARNING_RATE = 0.001  # Define learning rate

model = build_resnet(input_shape=(H, W, 3))
model.compile(
    loss=soft_dice_loss,  # <-- CHANGED: switch to Dice loss
    optimizer=Adam(LEARNING_RATE),
    metrics=[soft_dice_coef, iou, Recall(), Precision()]
)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tf.keras.layers import Input, Conv2D, BatchNormalization, LeakyReLU, Add, GlobalAveragePooling2D, Dense, MaxPool2D, Conv2DTranspose, Concatenate
#       2 from tf.keras.models import Model
#       3 from tf.keras.optimizers import Adam
#
# ModuleNotFoundError: No module named 'tf'

# %% [markdown]
# *Checking length of Train,Val,Test*

# %%
print("Train size:", len(train_x))
print("Val size:", len(val_x))
print("Test size:", len(test_x))
# Out:
# Train size: 3984
# Val size: 1246
# Test size: 996

# %%
for batch_idx, (xx, yy) in enumerate(train_dataset.take(1)):
    print("Batch", batch_idx)
    print("X shape:", xx.shape, xx.dtype)
    print("Y shape:", yy.shape, yy.dtype)
# Out:
# Batch 0
# X shape: (8, 256, 256, 3) <dtype: 'float32'>
# Y shape: (8, 256, 256, 1) <dtype: 'float32'>

# %% [markdown]
# *Model Training*

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_recall',
        factor=0.1,
        patience=2,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_recall',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
]

history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_data=val_dataset,
    validation_steps=val_steps,
    callbacks=callbacks   # <-- ADDED
)
# Out:
# Epoch 1/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 194s 301ms/step - iou: 0.1647 - loss: 0.7290 - precision: 0.2310 - recall: 0.4660 - soft_dice_coef: 0.2710 - val_iou: 0.0407 - val_loss: 0.9221 - val_precision: 0.7956 - val_recall: 0.0325 - val_soft_dice_coef: 0.0779 - learning_rate: 0.0010
# Epoch 2/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 140s 282ms/step - iou: 0.3594 - loss: 0.4749 - precision: 0.6644 - recall: 0.4615 - soft_dice_coef: 0.5251 - val_iou: 0.0990 - val_loss: 0.8230 - val_precision: 0.8575 - val_recall: 0.0790 - val_soft_dice_coef: 0.1770 - learning_rate: 0.0010
# Epoch 3/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - iou: 0.4034 - loss: 0.4281 - precision: 0.7190 - recall: 0.4958 - soft_dice_coef: 0.5719
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 140s 280ms/step - iou: 0.4035 - loss: 0.4281 - precision: 0.7191 - recall: 0.4958 - soft_dice_coef: 0.5719 - val_iou: 0.1699 - val_loss: 0.7154 - val_precision: 0.7756 - val_recall: 0.1545 - val_soft_dice_coef: 0.2846 - learning_rate: 0.0010
# Epoch 4/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 140s 280ms/step - iou: 0.4488 - loss: 0.3832 - precision: 0.7734 - recall: 0.5256 - soft_dice_coef: 0.6168 - val_iou: 0.4531 - val_loss: 0.3794 - val_precision: 0.7979 - val_recall: 0.5275 - val_soft_dice_coef: 0.6206 - learning_rate: 1.0000e-04
# Epoch 5/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - iou: 0.4663 - loss: 0.3667 - precision: 0.7847 - recall: 0.5439 - soft_dice_coef: 0.6333
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 139s 280ms/step - iou: 0.4663 - loss: 0.3667 - precision: 0.7847 - recall: 0.5439 - soft_dice_coef: 0.6333 - val_iou: 0.4570 - val_loss: 0.3756 - val_precision: 0.8120 - val_recall: 0.5190 - val_soft_dice_coef: 0.6244 - learning_rate: 1.0000e-04
# Epoch 6/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 138s 277ms/step - iou: 0.4735 - loss: 0.3600 - precision: 0.7900 - recall: 0.5522 - soft_dice_coef: 0.6400 - val_iou: 0.4697 - val_loss: 0.3633 - val_precision: 0.8007 - val_recall: 0.5460 - val_soft_dice_coef: 0.6367 - learning_rate: 1.0000e-05
# Epoch 7/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - iou: 0.4749 - loss: 0.3587 - precision: 0.7917 - recall: 0.5524 - soft_dice_coef: 0.6413
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 135s 271ms/step - iou: 0.4749 - loss: 0.3587 - precision: 0.7917 - recall: 0.5524 - soft_dice_coef: 0.6413 - val_iou: 0.4721 - val_loss: 0.3612 - val_precision: 0.8003 - val_recall: 0.5498 - val_soft_dice_coef: 0.6388 - learning_rate: 1.0000e-05
# Epoch 8/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 136s 273ms/step - iou: 0.4758 - loss: 0.3579 - precision: 0.7883 - recall: 0.5582 - soft_dice_coef: 0.6421 - val_iou: 0.4707 - val_loss: 0.3627 - val_precision: 0.7991 - val_recall: 0.5502 - val_soft_dice_coef: 0.6373 - learning_rate: 1.0000e-06
# Epoch 9/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - iou: 0.4758 - loss: 0.3579 - precision: 0.7913 - recall: 0.5546 - soft_dice_coef: 0.6421
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 134s 270ms/step - iou: 0.4758 - loss: 0.3579 - precision: 0.7913 - recall: 0.5546 - soft_dice_coef: 0.6421 - val_iou: 0.4720 - val_loss: 0.3613 - val_precision: 0.8011 - val_recall: 0.5487 - val_soft_dice_coef: 0.6387 - learning_rate: 1.0000e-06
# Epoch 10/10
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 134s 269ms/step - iou: 0.4763 - loss: 0.3574 - precision: 0.7927 - recall: 0.5539 - soft_dice_coef: 0.6426 - val_iou: 0.4725 - val_loss: 0.3608 - val_precision: 0.8001 - val_recall: 0.5496 - val_soft_dice_coef: 0.6392 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 8.

# %% [markdown]
# *Model Saving*

# %%
model.save('/kaggle/working/road_extraction_Resnet.h5')

# %% [markdown]
# *User's Prediction*

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Load your trained model
model_path = "/kaggle/working/road_extraction_Resnet.h5"
model = tf.keras.models.load_model(model_path, compile=False)  # Load without compilation if necessary

def read_image(image_path, target_size=(256, 256)):  
    """ Reads and preprocesses the input image. """
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Read in color mode
    if img is None:
        print(f"Error: Unable to read image at {image_path}")
        return None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, target_size)  # Resize to match model input shape
    img = img / 255.0  # Normalize pixel values (0-1)
    return img

# Provide the image path directly
image_path = "/kaggle/input/deepglobe-road-extraction-dataset/train/100034_sat.jpg"  # Update with actual path

# Read and process the image
sample_img = read_image(image_path)

if sample_img is not None:
    sample_img_expanded = np.expand_dims(sample_img, axis=0)
    prediction = model.predict(sample_img_expanded)[0]

    plt.figure(figsize=(12, 6))
    
    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(sample_img)
    plt.title('Original Image')
    plt.axis('off')

    # Predicted Mask
    plt.subplot(1, 2, 2)
    plt.imshow(prediction.squeeze(), cmap='gray')
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.show()
else:
    print("Error: Image could not be loaded. Please check the file path.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# *Visualizing Loss*

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Use the actual number of epochs that were run:
epochs_ran = len(training_loss)

plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs_ran + 1), training_loss, label='Training Loss')
plt.plot(range(1, epochs_ran + 1), validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()
